# %%
from pycaret.datasets import get_data

# Import the iris dataset
data = get_data('iris')
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


# Load the IRIS dataset
from sklearn.datasets import load_iris
iris = load_iris()

# Convert the IRIS dataset to a Pandas DataFrame
df = pd.DataFrame(iris.data, columns=iris.feature_names)

# Create a histogram for each feature
sns.set(style="dark")
for col in df.columns:
    sns.histplot(df[col], kde=True)
    plt.title(col)
    plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# Carga el conjunto de datos Iris
from pycaret.datasets import get_data

data = get_data('iris')
sns.set_style('darkgrid')
colors = ['#851836', '#EDBD17', '#0E1428', '#407076', '#4C5B61']
sns.set_palette(sns.color_palette(colors))


# Crea un subplot de 2x2
fig, axs = plt.subplots(2, 2)

# Crea un sns.histplot de la longitud del sépalo para cada clase de iris
sns.histplot(data=data, x="sepal_length", hue="species", ax=axs[0, 0], bins=10, kde=True)

# Crea un sns.histplot del ancho del sépalo para cada clase de iris
sns.histplot(data=data, x="sepal_width", hue="species", ax=axs[0, 1], bins=10, kde=True)

# Crea un sns.histplot de la longitud del pétalo para cada clase de iris
sns.histplot(data=data, x="petal_length", hue="species", ax=axs[1, 0], bins=10, kde=True)

# Crea un sns.histplot del ancho del pétalo para cada clase de iris
sns.histplot(data=data, x="petal_width", hue="species", ax=axs[1, 1], bins=10, kde=True)

# Personaliza los ejes
for ax in axs.flat:
    ax.set_ylabel("Frecuencia")
    ax.set_xlabel("Valor")

# Guarda la figura
plt.savefig("iris_histograms.png")

# Muestra la figura
plt.show()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
import matplotlib.pyplot as plt
import seaborn
from pycaret.datasets import get_data
import sys

data = get_data('iris')
sns.set_style('darkgrid')
colors = ['#851836', '#EDBD17', '#0E1428', '#407076', '#4C5B61']
sns.set_palette(sns.color_palette(colors))

#Crea un subplot de 2x2
fig, axs = plt.subplots(2, 2)

# Crea un boxplot de la longitud del sépalo para cada clase de iris
sns.boxplot(x="species", y="sepal_length", data=data,ax=axs[0, 0])

# Crea un boxplot del ancho del sépalo para cada clase de iris
sns.boxplot(x="species", y="sepal_width", data=data,ax=axs[0, 1])

# Crea un boxplot de la longitud del pétalo para cada clase de iris
sns.boxplot(x="species", y="petal_length", data=data,ax=axs[1, 0])

# Crea un boxplot del ancho del pétalo para cada clase de iris
sns.boxplot(x="species", y="petal_width", data=data,ax=axs[1, 1])
# Guarda la figura
#plt.savefig("iris_histograms.png")
plt.tight_layout()
plt.savefig(sys.stdout.buffer)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 28
#      25 # Guarda la figura
#      26 #plt.savefig("iris_histograms.png")
#      27 plt.tight_layout()
# ---> 28 plt.savefig(sys.stdout.buffer)
#
# AttributeError: 'OutStream' object has no attribute 'buffer'

# %%
from pycaret.classification import setup

# Inicializar el entorno
clf = setup(data, target = 'species', train_size = 0.8, session_id = 123, normalize = True)
# Out:
# <style type="text/css">
# #T_ff69b_row9_col1, #T_ff69b_row13_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_ff69b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ff69b_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_ff69b_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ff69b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ff69b_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_ff69b_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_ff69b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ff69b_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_ff69b_row1_col1" class="data row1 col1" >species</td>
#     </tr>
#     <tr>
#       <th id="T_ff69b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ff69b_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_ff69b_row2_col1" class="data row2 col1" >Multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_ff69b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ff69b_row3_col0" class="data row3 col0" >Target mapping</td>
#       <td id="T_ff69b_row3_col1" class="data row3 col1" >Iris-setosa: 0, Iris-versicolor: 1, Iris-virginica: 2</td>
#     </tr>
#     <tr>
#       <th id="T_ff69b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ff69b_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_ff69b_row4_col1" class="data row4 col1" >(150, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_ff69b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_ff69b_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_ff69b_row5_col1" class="data row5 col1" >(150, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_ff69b_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_ff69b_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_ff69b_row6_col1" class="data row6 col1" >(120, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_ff69b_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_ff69b_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_ff69b_row7_col1" class="data row7 col1" >(30, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_ff69b_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_ff69b_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_ff69b_row8_col1" class="data row8 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_ff69b_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_ff69b_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_ff69b_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_ff69b_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_ff69b_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_ff69b_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_ff69b_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_ff69b_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_ff69b_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_ff69b_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_ff69b_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_ff69b_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_ff69b_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_ff69b_row13_col0" class="data row13 col0" >Normalize</td>
#       <td id="T_ff69b_row13_col1" class="data row13 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_ff69b_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_ff69b_row14_col0" class="data row14 col0" >Normalize method</td>
#       <td id="T_ff69b_row14_col1" class="data row14 col1" >zscore</td>
#     </tr>
#     <tr>
#       <th id="T_ff69b_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_ff69b_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_ff69b_row15_col1" class="data row15 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_ff69b_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_ff69b_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_ff69b_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_ff69b_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_ff69b_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_ff69b_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_ff69b_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_ff69b_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_ff69b_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_ff69b_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_ff69b_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_ff69b_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_ff69b_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_ff69b_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_ff69b_row20_col1" class="data row20 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_ff69b_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_ff69b_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_ff69b_row21_col1" class="data row21 col1" >13da</td>
#     </tr>
#   </tbody>
# </table>

# %%
print(clf.data.head())
# Out:
#    sepal_length  sepal_width  petal_length  petal_width          species
# 0           5.7          2.8           4.1          1.3  Iris-versicolor
# 1           5.0          3.2           1.2          0.2      Iris-setosa
# 2           6.3          2.3           4.4          1.3  Iris-versicolor
# 3           5.4          3.9           1.7          0.4      Iris-setosa
# 4           5.4          3.7           1.5          0.2      Iris-setosa

# %%
import pycaret
pycaret.classification.get_config('X')
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.7          2.8           4.1          1.3
# 1             5.0          3.2           1.2          0.2
# 2             6.3          2.3           4.4          1.3
# 3             5.4          3.9           1.7          0.4
# 4             5.4          3.7           1.5          0.2
# ..            ...          ...           ...          ...
# 145           6.3          2.5           5.0          1.9
# 146           5.0          2.3           3.3          1.0
# 147           6.7          3.1           4.7          1.5
# 148           6.2          2.2           4.5          1.5
# 149           6.7          3.1           4.4          1.4
#
# [150 rows x 4 columns]

# %%
models = clf.compare_models()

# Imprimir los resultados de la comparación
print(models)
# Out:
# <style type="text/css">
# #T_9f361 th {
#   text-align: left;
# }
# #T_9f361_row0_col0, #T_9f361_row1_col0, #T_9f361_row2_col0, #T_9f361_row2_col1, #T_9f361_row2_col2, #T_9f361_row2_col3, #T_9f361_row2_col4, #T_9f361_row2_col5, #T_9f361_row2_col6, #T_9f361_row2_col7, #T_9f361_row3_col0, #T_9f361_row3_col1, #T_9f361_row3_col2, #T_9f361_row3_col3, #T_9f361_row3_col4, #T_9f361_row3_col5, #T_9f361_row3_col6, #T_9f361_row3_col7, #T_9f361_row4_col0, #T_9f361_row4_col1, #T_9f361_row4_col2, #T_9f361_row4_col3, #T_9f361_row4_col4, #T_9f361_row4_col5, #T_9f361_row4_col6, #T_9f361_row4_col7, #T_9f361_row5_col0, #T_9f361_row5_col1, #T_9f361_row5_col2, #T_9f361_row5_col3, #T_9f361_row5_col4, #T_9f361_row5_col5, #T_9f361_row5_col6, #T_9f361_row5_col7, #T_9f361_row6_col0, #T_9f361_row6_col1, #T_9f361_row6_col2, #T_9f361_row6_col3, #T_9f361_row6_col4, #T_9f361_row6_col5, #T_9f361_row6_col6, #T_9f361_row6_col7, #T_9f361_row7_col0, #T_9f361_row7_col1, #T_9f361_row7_col2, #T_9f361_row7_col3, #T_9f361_row7_col4, #T_9f361_row7_col5, #T_9f361_row7_col6, #T_9f361_row7_col7, #T_9f361_row8_col0, #T_9f361_row8_col1, #T_9f361_row8_col2, #T_9f361_row8_col3, #T_9f361_row8_col4, #T_9f361_row8_col5, #T_9f361_row8_col6, #T_9f361_row8_col7, #T_9f361_row9_col0, #T_9f361_row9_col1, #T_9f361_row9_col2, #T_9f361_row9_col3, #T_9f361_row9_col4, #T_9f361_row9_col5, #T_9f361_row9_col6, #T_9f361_row9_col7, #T_9f361_row10_col0, #T_9f361_row10_col1, #T_9f361_row10_col2, #T_9f361_row10_col3, #T_9f361_row10_col4, #T_9f361_row10_col5, #T_9f361_row10_col6, #T_9f361_row10_col7, #T_9f361_row11_col0, #T_9f361_row11_col1, #T_9f361_row11_col2, #T_9f361_row11_col3, #T_9f361_row11_col4, #T_9f361_row11_col5, #T_9f361_row11_col6, #T_9f361_row11_col7, #T_9f361_row12_col0, #T_9f361_row12_col1, #T_9f361_row12_col2, #T_9f361_row12_col3, #T_9f361_row12_col4, #T_9f361_row12_col5, #T_9f361_row12_col6, #T_9f361_row12_col7, #T_9f361_row13_col0, #T_9f361_row13_col1, #T_9f361_row13_col2, #T_9f361_row13_col3, #T_9f361_row13_col4, #T_9f361_row13_col5, #T_9f361_row13_col6, #T_9f361_row13_col7, #T_9f361_row14_col0, #T_9f361_row14_col1, #T_9f361_row14_col2, #T_9f361_row14_col3, #T_9f361_row14_col4, #T_9f361_row14_col5, #T_9f361_row14_col6, #T_9f361_row14_col7 {
#   text-align: left;
# }
# #T_9f361_row0_col1, #T_9f361_row0_col2, #T_9f361_row0_col3, #T_9f361_row0_col4, #T_9f361_row0_col5, #T_9f361_row0_col6, #T_9f361_row0_col7, #T_9f361_row1_col1, #T_9f361_row1_col2, #T_9f361_row1_col3, #T_9f361_row1_col4, #T_9f361_row1_col5, #T_9f361_row1_col6, #T_9f361_row1_col7 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_9f361_row0_col8, #T_9f361_row1_col8, #T_9f361_row2_col8, #T_9f361_row3_col8, #T_9f361_row4_col8, #T_9f361_row5_col8, #T_9f361_row6_col8, #T_9f361_row7_col8, #T_9f361_row8_col8, #T_9f361_row9_col8, #T_9f361_row10_col8, #T_9f361_row11_col8, #T_9f361_row12_col8, #T_9f361_row14_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_9f361_row13_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_9f361">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9f361_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_9f361_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_9f361_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_9f361_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_9f361_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_9f361_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_9f361_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_9f361_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_9f361_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9f361_level0_row0" class="row_heading level0 row0" >qda</th>
#       <td id="T_9f361_row0_col0" class="data row0 col0" >Quadratic Discriminant Analysis</td>
#       <td id="T_9f361_row0_col1" class="data row0 col1" >0.9750</td>
#       <td id="T_9f361_row0_col2" class="data row0 col2" >1.0000</td>
#       <td id="T_9f361_row0_col3" class="data row0 col3" >0.9750</td>
#       <td id="T_9f361_row0_col4" class="data row0 col4" >0.9800</td>
#       <td id="T_9f361_row0_col5" class="data row0 col5" >0.9746</td>
#       <td id="T_9f361_row0_col6" class="data row0 col6" >0.9625</td>
#       <td id="T_9f361_row0_col7" class="data row0 col7" >0.9653</td>
#       <td id="T_9f361_row0_col8" class="data row0 col8" >0.0170</td>
#     </tr>
#     <tr>
#       <th id="T_9f361_level0_row1" class="row_heading level0 row1" >lda</th>
#       <td id="T_9f361_row1_col0" class="data row1 col0" >Linear Discriminant Analysis</td>
#       <td id="T_9f361_row1_col1" class="data row1 col1" >0.9750</td>
#       <td id="T_9f361_row1_col2" class="data row1 col2" >1.0000</td>
#       <td id="T_9f361_row1_col3" class="data row1 col3" >0.9750</td>
#       <td id="T_9f361_row1_col4" class="data row1 col4" >0.9800</td>
#       <td id="T_9f361_row1_col5" class="data row1 col5" >0.9746</td>
#       <td id="T_9f361_row1_col6" class="data row1 col6" >0.9625</td>
#       <td id="T_9f361_row1_col7" class="data row1 col7" >0.9653</td>
#       <td id="T_9f361_row1_col8" class="data row1 col8" >0.0180</td>
#     </tr>
#     <tr>
#       <th id="T_9f361_level0_row2" class="row_heading level0 row2" >lr</th>
#       <td id="T_9f361_row2_col0" class="data row2 col0" >Logistic Regression</td>
#       <td id="T_9f361_row2_col1" class="data row2 col1" >0.9667</td>
#       <td id="T_9f361_row2_col2" class="data row2 col2" >0.9969</td>
#       <td id="T_9f361_row2_col3" class="data row2 col3" >0.9667</td>
#       <td id="T_9f361_row2_col4" class="data row2 col4" >0.9733</td>
#       <td id="T_9f361_row2_col5" class="data row2 col5" >0.9661</td>
#       <td id="T_9f361_row2_col6" class="data row2 col6" >0.9500</td>
#       <td id="T_9f361_row2_col7" class="data row2 col7" >0.9537</td>
#       <td id="T_9f361_row2_col8" class="data row2 col8" >0.4590</td>
#     </tr>
#     <tr>
#       <th id="T_9f361_level0_row3" class="row_heading level0 row3" >knn</th>
#       <td id="T_9f361_row3_col0" class="data row3 col0" >K Neighbors Classifier</td>
#       <td id="T_9f361_row3_col1" class="data row3 col1" >0.9583</td>
#       <td id="T_9f361_row3_col2" class="data row3 col2" >0.9969</td>
#       <td id="T_9f361_row3_col3" class="data row3 col3" >0.9583</td>
#       <td id="T_9f361_row3_col4" class="data row3 col4" >0.9689</td>
#       <td id="T_9f361_row3_col5" class="data row3 col5" >0.9568</td>
#       <td id="T_9f361_row3_col6" class="data row3 col6" >0.9375</td>
#       <td id="T_9f361_row3_col7" class="data row3 col7" >0.9436</td>
#       <td id="T_9f361_row3_col8" class="data row3 col8" >0.1980</td>
#     </tr>
#     <tr>
#       <th id="T_9f361_level0_row4" class="row_heading level0 row4" >lightgbm</th>
#       <td id="T_9f361_row4_col0" class="data row4 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_9f361_row4_col1" class="data row4 col1" >0.9583</td>
#       <td id="T_9f361_row4_col2" class="data row4 col2" >0.9917</td>
#       <td id="T_9f361_row4_col3" class="data row4 col3" >0.9583</td>
#       <td id="T_9f361_row4_col4" class="data row4 col4" >0.9633</td>
#       <td id="T_9f361_row4_col5" class="data row4 col5" >0.9579</td>
#       <td id="T_9f361_row4_col6" class="data row4 col6" >0.9375</td>
#       <td id="T_9f361_row4_col7" class="data row4 col7" >0.9403</td>
#       <td id="T_9f361_row4_col8" class="data row4 col8" >0.1260</td>
#     </tr>
#     <tr>
#       <th id="T_9f361_level0_row5" class="row_heading level0 row5" >rf</th>
#       <td id="T_9f361_row5_col0" class="data row5 col0" >Random Forest Classifier</td>
#       <td id="T_9f361_row5_col1" class="data row5 col1" >0.9500</td>
#       <td id="T_9f361_row5_col2" class="data row5 col2" >0.9958</td>
#       <td id="T_9f361_row5_col3" class="data row5 col3" >0.9500</td>
#       <td id="T_9f361_row5_col4" class="data row5 col4" >0.9567</td>
#       <td id
# QuadraticDiscriminantAnalysis(priors=None, reg_param=0.0,
#                               store_covariance=False, tol=0.0001)

# %%
# Crear un modelo de Random Forest
rf = clf.create_model("rf")
# Ajustar el modelo
#datos de entrada y salida
rf.fit()
# Out:
# <style type="text/css">
# #T_5a208_row10_col0, #T_5a208_row10_col1, #T_5a208_row10_col2, #T_5a208_row10_col3, #T_5a208_row10_col4, #T_5a208_row10_col5, #T_5a208_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_5a208">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5a208_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_5a208_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_5a208_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_5a208_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_5a208_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_5a208_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_5a208_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5a208_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5a208_row0_col0" class="data row0 col0" >1.0000</td>
#       <td id="T_5a208_row0_col1" class="data row0 col1" >1.0000</td>
#       <td id="T_5a208_row0_col2" class="data row0 col2" >1.0000</td>
#       <td id="T_5a208_row0_col3" class="data row0 col3" >1.0000</td>
#       <td id="T_5a208_row0_col4" class="data row0 col4" >1.0000</td>
#       <td id="T_5a208_row0_col5" class="data row0 col5" >1.0000</td>
#       <td id="T_5a208_row0_col6" class="data row0 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_5a208_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5a208_row1_col0" class="data row1 col0" >0.9167</td>
#       <td id="T_5a208_row1_col1" class="data row1 col1" >1.0000</td>
#       <td id="T_5a208_row1_col2" class="data row1 col2" >0.9167</td>
#       <td id="T_5a208_row1_col3" class="data row1 col3" >0.9333</td>
#       <td id="T_5a208_row1_col4" class="data row1 col4" >0.9153</td>
#       <td id="T_5a208_row1_col5" class="data row1 col5" >0.8750</td>
#       <td id="T_5a208_row1_col6" class="data row1 col6" >0.8843</td>
#     </tr>
#     <tr>
#       <th id="T_5a208_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5a208_row2_col0" class="data row2 col0" >1.0000</td>
#       <td id="T_5a208_row2_col1" class="data row2 col1" >1.0000</td>
#       <td id="T_5a208_row2_col2" class="data row2 col2" >1.0000</td>
#       <td id="T_5a208_row2_col3" class="data row2 col3" >1.0000</td>
#       <td id="T_5a208_row2_col4" class="data row2 col4" >1.0000</td>
#       <td id="T_5a208_row2_col5" class="data row2 col5" >1.0000</td>
#       <td id="T_5a208_row2_col6" class="data row2 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_5a208_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_5a208_row3_col0" class="data row3 col0" >0.8333</td>
#       <td id="T_5a208_row3_col1" class="data row3 col1" >0.9792</td>
#       <td id="T_5a208_row3_col2" class="data row3 col2" >0.8333</td>
#       <td id="T_5a208_row3_col3" class="data row3 col3" >0.8333</td>
#       <td id="T_5a208_row3_col4" class="data row3 col4" >0.8333</td>
#       <td id="T_5a208_row3_col5" class="data row3 col5" >0.7500</td>
#       <td id="T_5a208_row3_col6" class="data row3 col6" >0.7500</td>
#     </tr>
#     <tr>
#       <th id="T_5a208_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_5a208_row4_col0" class="data row4 col0" >1.0000</td>
#       <td id="T_5a208_row4_col1" class="data row4 col1" >1.0000</td>
#       <td id="T_5a208_row4_col2" class="data row4 col2" >1.0000</td>
#       <td id="T_5a208_row4_col3" class="data row4 col3" >1.0000</td>
#       <td id="T_5a208_row4_col4" class="data row4 col4" >1.0000</td>
#       <td id="T_5a208_row4_col5" class="data row4 col5" >1.0000</td>
#       <td id="T_5a208_row4_col6" class="data row4 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_5a208_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_5a208_row5_col0" class="data row5 col0" >0.9167</td>
#       <td id="T_5a208_row5_col1" class="data row5 col1" >0.9792</td>
#       <td id="T_5a208_row5_col2" class="data row5 col2" >0.9167</td>
#       <td id="T_5a208_row5_col3" class="data row5 col3" >0.9333</td>
#       <td id="T_5a208_row5_col4" class="data row5 col4" >0.9153</td>
#       <td id="T_5a208_row5_col5" class="data row5 col5" >0.8750</td>
#       <td id="T_5a208_row5_col6" class="data row5 col6" >0.8843</td>
#     </tr>
#     <tr>
#       <th id="T_5a208_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_5a208_row6_col0" class="data row6 col0" >1.0000</td>
#       <td id="T_5a208_row6_col1" class="data row6 col1" >1.0000</td>
#       <td id="T_5a208_row6_col2" class="data row6 col2" >1.0000</td>
#       <td id="T_5a208_row6_col3" class="data row6 col3" >1.0000</td>
#       <td id="T_5a208_row6_col4" class="data row6 col4" >1.0000</td>
#       <td id="T_5a208_row6_col5" class="data row6 col5" >1.0000</td>
#       <td id="T_5a208_row6_col6" class="data row6 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_5a208_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_5a208_row7_col0" class="data row7 col0" >0.9167</td>
#       <td id="T_5a208_row7_col1" class="data row7 col1" >1.0000</td>
#       <td id="T_5a208_row7_col2" class="data row7 col2" >0.9167</td>
#       <td id="T_5a208_row7_col3" class="data row7 col3" >0.9333</td>
#       <td id="T_5a208_row7_col4" class="data row7 col4" >0.9153</td>
#       <td id="T_5a208_row7_col5" class="data row7 col5" >0.8750</td>
#       <td id="T_5a208_row7_col6" class="data row7 col6" >0.8843</td>
#     </tr>
#     <tr>
#       <th id="T_5a208_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_5a208_row8_col0" class="data row8 col0" >0.9167</td>
#       <td id="T_5a208_row8_col1" class="data row8 col1" >1.0000</td>
#       <td id="T_5a208_row8_col2" class="data row8 col2" >0.9167</td>
#       <td id="T_5a208_row8_col3" class="data row8 col3" >0.9333</td>
#       <td id="T_5a208_row8_col4" class="data row8 col4" >0.9153</td>
#       <td id="T_5a208_row8_col5" class="data row8 col5" >0.8750</td>
#       <td id="T_5a208_row8_col6" class="data row8 col6" >0.8843</td>
#     </tr>
#     <tr>
#       <th id="T_5a208_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_5a208_row9_col0" class="data row9 col0" >1.0000</td>
#       <td id="T_5a208_row9_col1" class="data row9 col1" >1.0000</td>
#       <td id="T_5a208_row9_col2" class="data row9 col2" >1.0000</td>
#       <td id="T_5a208_row9_col3" class="data row9 col3" >1.0000</td>
#       <td id="T_5a208_row9_col4" class="data row9 col4" >1.0000</td>
#       <td id="T_5a208_row9_col5" class="data row9 col5" >1.0000</td>
#       <td id="T_5a208_row9_col6" class="data row9 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_5a208_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_5a208_row10_col0" class="data row10 col0" >0.9500</td>
#       <td id="T_5a208_row10_col1" class="data row10 col1" >0.9958</td>
#       <td id="T_5a208_row10_col2" class="data row10 col2" >0.9500</td>
#       <td id="T_5a208_row10_col3" class="data row10 col3" >0.9567</td>
#       <td id="T_5a208_row10_col4" class="data row10 col4" >0.9495</td>
#       <td id="T_5a208_row10_col5" class="data row10 col5" >0.9250</td>
#       <td id="T_5a208_row10_col6" class="data row10 col6" >0.9287</td>
#     </tr>
#     <tr>
#       <th id="T_5a208_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_5a208_row11_col0" class="data row11 col0" >0.0553</td>
#       <td id="T_5a208_row11_col1" class="data row11 col1" >0.0083</td>
#       <td id="T_5a208_row11_col2" class="data row11 col2" >0.0553</td>
#       <td id="T_5a208_row11_col3" class="data row11 col3" >0.0517</td>
#       <td id="T_5a208_row11_col4
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 5
#       2 rf = clf.create_model("rf")
#       3 # Ajustar el modelo
#       4 #datos de entrada y salida
# ----> 5 rf.fit()
#
# TypeError: BaseForest.fit() missing 2 required positional arguments: 'X' and 'y'

# %%
# Trazar el rendimiento del modelo
rf.plot_model()

# %%
# Hacer predicciones sobre nuevos datos
predictions = rf.predict(data.drop("species", axis=1))

# %%
# Importar el módulo SHAP
from pycaret.explainers import shap

# Obtener las explicaciones del modelo
shap_values = shap.explain_model(rf, data.drop("Survived", axis=1))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[21], line 2
#       1 # Importar el módulo SHAP
# ----> 2 from pycaret.explainers import shap
#       4 # Obtener las explicaciones del modelo
#       5 shap_values = shap.explain_model(rf, data.drop("Survived", axis=1))
#
# ModuleNotFoundError: No module named 'pycaret.explainers'

# %%
# Visualizar las explicaciones del modelo
shap.plots.bar(shap_values)
